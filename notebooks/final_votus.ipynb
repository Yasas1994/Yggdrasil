# %%
import pandas as pd

# %%
final = open("final_votu_ids.txt").read().split("\n")

# %%
all_ = pd.read_csv("./votu_master.tsv", sep="\t")

# %%
all_[all_["representative"].isin(final)]
# Out:
#       votu               representative  n_members  n_samples  rep_length  \
# 27    1021  Kenneth019__Kenneth019_2339          1          1       20442
# 48    1040  Kenneth015__Kenneth015_1126          1          1       19451
# 83    1072  Kenneth016__Kenneth016_1323          1          1       18546
# 147    113   Kenneth016__Kenneth016_452          9          6       36841
# 149   1131  Kenneth019__Kenneth019_3162          1          1       16144
# ...    ...                          ...        ...        ...         ...
# 1730   905  Kenneth019__Kenneth019_1197          1          1       32351
# 1731   906  Kenneth019__Kenneth019_1205          1          1       32183
# 1754   927  Kenneth019__Kenneth019_1425          1          1       28909
# 1791   960  Kenneth028__Kenneth028_1557          1          1       25111
# 1796   965   Kenneth016__Kenneth016_872          1          1       24421
#
#       checkv_quality  completeness  contamination  \
# ...
